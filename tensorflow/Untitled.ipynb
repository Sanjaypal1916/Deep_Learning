# %%
import tensorflow as  tf

# %%
tf.is_gpu_available()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 tf.is_gpu_available()
#
# AttributeError: module 'tensorflow' has no attribute 'is_gpu_available'

# %%
tf.config.list_physical_devices('GPU')
# Out:
# []

# %%
tf.test.is_built_with_cuda()
# Out:
# False

# %%
tf.__version__
# Out:
# '2.18.0'

# %%
# !python --version
# Out:
# Python 3.12.7

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\sanjay\AppData\Local\Temp\ipykernel_1948\2294581100.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %%
# !python --version
# Out:
# Python 3.12.7

# %%
# !conda activate py310

# %%
# !python --version
# Out:
# Python 3.12.7

# %%
tf.test.
